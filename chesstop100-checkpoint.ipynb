# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\samsung\Anaconda3\lib\site-packages\pandas\compat\_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
chess = pd.read_csv("Chesstop100.csv")
df = chess.copy()
df.head()
# Out:
#                      NAME COUNTRY  AGE  CURRENT ELO  12 AGE ELO  18 AGE ELO  \
# 0         Carlsen, Magnus     NOR   33         2830      2450.0        2801
# 1        Caruana, Fabiano     ABD   31         2803      2381.0        2721
# 2        Nakamura, Hikaru     ABD   36         2789      2356.0        2664
# 3  Abdusattorov, Nodirbek   UZBEK   19         2765      2486.0        2734
# 4             Ding, Liren     CHI   31         2762      2289.0        2664
#
#    TOTAL GAMES  WINS  LOSSES  DRAWS
# 0         3421  1536     527   1358
# 1         3047  1187     641   1219
# 2         3318  1426     567   1325
# 3         1160   513     240    407
# 4         1489   510     229    750

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   NAME         100 non-null    object
#  1   COUNTRY      100 non-null    object
#  2   AGE          100 non-null    int64
#  3   CURRENT ELO  100 non-null    int64
#  4   12 AGE ELO   86 non-null     float64
#  5   18 AGE ELO   100 non-null    int64
#  6   TOTAL GAMES  100 non-null    int64
#  7   WINS         100 non-null    int64
#  8   LOSSES       100 non-null    int64
#  9   DRAWS        100 non-null    int64
# dtypes: float64(1), int64(7), object(2)
# memory usage: 7.9+ KB

# %%
df.describe().T
# Out:
#              count        mean         std     min      25%     50%      75%  \
# AGE          100.0    31.81000    8.819967    17.0    24.00    32.0    38.00
# CURRENT ELO  100.0  2692.69000   41.386987  2641.0  2661.00  2682.5  2727.00
# 12 AGE ELO    86.0  2311.27907  124.092722  2053.0  2217.75  2320.0  2401.00
# 18 AGE ELO   100.0  2629.45000   73.063052  2418.0  2581.75  2628.0  2684.25
# TOTAL GAMES  100.0  2000.15000  844.913400   585.0  1302.00  1877.5  2476.25
# WINS         100.0   807.03000  324.584877   229.0   559.75   752.0   953.00
# LOSSES       100.0   356.68000  144.281983    76.0   240.75   321.5   449.50
# DRAWS        100.0   835.64000  422.968311   260.0   507.75   739.5  1101.00
#
#                 max
# AGE            55.0
# CURRENT ELO  2830.0
# 12 AGE ELO   2550.0
# 18 AGE ELO   2804.0
# TOTAL GAMES  4382.0
# WINS         1927.0
# LOSSES        729.0
# DRAWS        2105.0

# %%
df.isnull().sum()
# Out:
# NAME            0
# COUNTRY         0
# AGE             0
# CURRENT ELO     0
# 12 AGE ELO     14
# 18 AGE ELO      0
# TOTAL GAMES     0
# WINS            0
# LOSSES          0
# DRAWS           0
# dtype: int64

# %%
plt.figure(figsize = (8,8))
sns.heatmap(df.corr(), annot = True, cmap = "PiYG" );

# %%
df.sort_values(by= "12 AGE ELO", ascending = False).head() # 12 yaşında elosu en yüksek 5 oyuncu
# Out:
#                   NAME COUNTRY  AGE  CURRENT ELO  12 AGE ELO  18 AGE ELO  \
# 90  Ponomariov, Ruslan     UKR   40         2646      2550.0        2743
# 11    Karjakin, Sergey    FIDE   34         2750      2547.0        2732
# 15            Gukesh D     IND   17         2743      2536.0        2758
# 13    Praggnanandhaa R     IND   18         2747      2532.0        2747
# 49  Sindarov, Javokhir   UZBEK   18         2684      2513.0        2701
#
#     TOTAL GAMES  WINS  LOSSES  DRAWS
# 90         2356   820     435   1101
# 11         3189  1167     595   1427
# 15         1274   606     295    373
# 13         1099   489     221    389
# 49          970   465     207    298

# %%
df.sort_values(by= "12 AGE ELO").head() # 12 yaşında elosu en düşük 5 oyuncu
# Out:
#                      NAME COUNTRY  AGE  CURRENT ELO  12 AGE ELO  18 AGE ELO  \
# 99        Yilmaz, Mustafa     TUR   31         2641      2053.0        2519
# 60  Anton Guijarro, David     SPA   28         2673      2055.0        2631
# 40          Narayanan S L     IND   26         2695      2073.0        2541
# 17    Maghsoodloo, Parham    IRAN   23         2732      2083.0        2689
# 85     Bluebaum, Matthias     GER   26         2649      2091.0        2628
#
#     TOTAL GAMES  WINS  LOSSES  DRAWS
# 99         1632   704     327    601
# 60         1802   793     328    681
# 40         1086   474     191    421
# 17         1529   751     301    477
# 85         1681   708     285    688

# %%
df.sort_values(by= "18 AGE ELO", ascending = False).head() # 18 yaşında elosu en yüksek 5 oyuncu
# Out:
#                  NAME COUNTRY  AGE  CURRENT ELO  12 AGE ELO  18 AGE ELO  \
# 5   Firouzja, Alireza     FRA   20         2760      2485.0        2804
# 0     Carlsen, Magnus     NOR   33         2830      2450.0        2801
# 15           Gukesh D     IND   17         2743      2536.0        2758
# 9             Wei, Yi     CHI   24         2755      2401.0        2753
# 13   Praggnanandhaa R     IND   18         2747      2532.0        2747
#
#     TOTAL GAMES  WINS  LOSSES  DRAWS
# 5          1194   561     148    385
# 0          3421  1536     527   1358
# 15         1274   606     295    373
# 9          1290   511     188    591
# 13         1099   489     221    389

# %%
df.sort_values(by= "18 AGE ELO").head() # 18 yaşında elosu en düşük 5 oyuncu
# Out:
#                   NAME COUNTRY  AGE  CURRENT ELO  12 AGE ELO  18 AGE ELO  \
# 98             Ma, Qun     CHI   32         2641      2239.0        2418
# 88     Bartel, Mateusz     POL   39         2647      2170.0        2482
# 70      Najer, Evgeniy    FIDE   46         2663         NaN        2495
# 79  Kryvoruchko, Yuriy     UKR   37         2654         NaN        2498
# 58    Predke, Alexandr     SER   30         2673      2129.0        2509
#
#     TOTAL GAMES  WINS  LOSSES  DRAWS
# 98          585   229      76    280
# 88         2759  1192     562   1005
# 70         2317   952     471    894
# 79         1516   611     197    708
# 58         1587   717     326    544

# %%
age_dist = sns.distplot(df["AGE"]);
age_dist.set(xlabel = "Age", ylabel = "Frequency");

# %%
curelo_dist = sns.distplot(df["CURRENT ELO"]);
curelo_dist.set(xlabel = "Current Elo", ylabel = "Frequency");

# %%
eighteen_elo = sns.distplot(df["18 AGE ELO"]);
eighteen_elo.set(xlabel = "18 Age Elo", ylabel = "Frequency");

# %%
sns.boxplot(df["AGE"]);

# %%
sns.boxplot(df["CURRENT ELO"]); # Aykırı değer 2830. Magnus Carlsen

# %%
sns.boxplot(df["18 AGE ELO"]);

# %%
df.sort_values(by= "18 AGE ELO").head(1) # 18 yaş aykırı değeri
# Out:
#        NAME COUNTRY  AGE  CURRENT ELO  12 AGE ELO  18 AGE ELO  TOTAL GAMES  \
# 98  Ma, Qun     CHI   32         2641      2239.0        2418          585
#
#     WINS  LOSSES  DRAWS
# 98   229      76    280

# %%
sns.pairplot(df);

# %%
df["WIN RATE"]= df["WINS"]/df["TOTAL GAMES"]
df["LOSS RATE"]= df["LOSSES"]/df["TOTAL GAMES"]
df["DRAW RATE"]= df["DRAWS"]/df["TOTAL GAMES"]
df.head()
# Out:
#                      NAME COUNTRY  AGE  CURRENT ELO  12 AGE ELO  18 AGE ELO  \
# 0         Carlsen, Magnus     NOR   33         2830      2450.0        2801
# 1        Caruana, Fabiano     ABD   31         2803      2381.0        2721
# 2        Nakamura, Hikaru     ABD   36         2789      2356.0        2664
# 3  Abdusattorov, Nodirbek   UZBEK   19         2765      2486.0        2734
# 4             Ding, Liren     CHI   31         2762      2289.0        2664
#
#    TOTAL GAMES  WINS  LOSSES  DRAWS  WIN RATE  LOSS RATE  DRAW RATE
# 0         3421  1536     527   1358  0.448992   0.154049   0.396960
# 1         3047  1187     641   1219  0.389564   0.210371   0.400066
# 2         3318  1426     567   1325  0.429777   0.170886   0.399337
# 3         1160   513     240    407  0.442241   0.206897   0.350862
# 4         1489   510     229    750  0.342512   0.153794   0.503694

# %%
df.iloc[:,-3:].describe().T
# Out:
#            count      mean       std       min       25%       50%       75%  \
# WIN RATE   100.0  0.410745  0.050391  0.257701  0.384472  0.411933  0.445960
# LOSS RATE  100.0  0.181532  0.028739  0.123953  0.164712  0.179267  0.201669
# DRAW RATE  100.0  0.407066  0.066432  0.276856  0.361511  0.402379  0.452012
#
#                 max
# WIN RATE   0.516592
# LOSS RATE  0.248544
# DRAW RATE  0.589031

# %%
df.sort_values(by= "WIN RATE", ascending = False).head() # Kazanma oranı en yüksek 5 oyuncu
# Out:
#                           NAME COUNTRY  AGE  CURRENT ELO  12 AGE ELO  \
# 96               Nabaty, Tamir     ISR   32         2643         NaN
# 71  Aravindh, Chithambaram VR.     IND   24         2662      2270.0
# 17         Maghsoodloo, Parham    IRAN   23         2732      2083.0
# 52                Amin, Bassem     EGY   35         2678      2166.0
# 78          Alekseenko, Kirill     AUS   26         2655      2251.0
#
#     18 AGE ELO  TOTAL GAMES  WINS  LOSSES  DRAWS  WIN RATE  LOSS RATE  \
# 96        2514         1115   576     201    338  0.516592   0.180269
# 71        2617         1188   587     239    362  0.494108   0.201178
# 17        2689         1529   751     301    477  0.491171   0.196861
# 52        2535         1841   903     392    546  0.490494   0.212928
# 78        2576         1432   693     314    425  0.483939   0.219274
#
#     DRAW RATE
# 96   0.303139
# 71   0.304714
# 17   0.311969
# 52   0.296578
# 78   0.296788

# %%
df.sort_values(by= "WIN RATE").head() # Kazanma oranı en düşük 5 oyuncu
# Out:
#                    NAME COUNTRY  AGE  CURRENT ELO  12 AGE ELO  18 AGE ELO  \
# 67          Leko, Peter     HUN   44         2666      2460.0        2670
# 27    Radjabov, Teimour     AZE   37         2723      2459.0        2704
# 73       Gelfand, Boris     ISR   55         2661         NaN        2510
# 14          Giri, Anish     NET   29         2745      2261.0        2734
# 50  Tomashevsky, Evgeny    FIDE   36         2681      2365.0        2595
#
#     TOTAL GAMES  WINS  LOSSES  DRAWS  WIN RATE  LOSS RATE  DRAW RATE
# 67         2662   686     408   1568  0.257701   0.153268   0.589031
# 27         2136   622     382   1132  0.291199   0.178839   0.529963
# 73         3646  1071     688   1887  0.293747   0.188700   0.517553
# 14         2431   750     414   1267  0.308515   0.170300   0.521185
# 50         1817   578     244    995  0.318107   0.134287   0.547606

# %%
df.sort_values(by= "LOSS RATE",ascending = False).head() # Kaybetme oranı en yüksek 5 oyuncu
# Out:
#                    NAME COUNTRY  AGE  CURRENT ELO  12 AGE ELO  18 AGE ELO  \
# 80     Sadhwani, Raunak     IND   18         2654      2438.0        2654
# 26      Keymer, Vincent     GER   19         2726      2432.0        2721
# 54   Niemann, Hans Moke     ABD   20         2676      2342.0        2678
# 66  Van Foreest, Jorden     NET   24         2668      2172.0        2636
# 15             Gukesh D     IND   17         2743      2536.0        2758
#
#     TOTAL GAMES  WINS  LOSSES  DRAWS  WIN RATE  LOSS RATE  DRAW RATE
# 80         1030   444     256    330  0.431068   0.248544   0.320388
# 26         1148   508     282    358  0.442509   0.245645   0.311847
# 54         1145   553     275    317  0.482969   0.240175   0.276856
# 66         1901   804     441    656  0.422935   0.231983   0.345082
# 15         1274   606     295    373  0.475667   0.231554   0.292779

# %%
df.sort_values(by= "LOSS RATE").head() # Kaybetme oranı en düşük 5 oyuncu
# Out:
#                    NAME COUNTRY  AGE  CURRENT ELO  12 AGE ELO  18 AGE ELO  \
# 5     Firouzja, Alireza     FRA   20         2760      2485.0        2804
# 98              Ma, Qun     CHI   32         2641      2239.0        2418
# 79   Kryvoruchko, Yuriy     UKR   37         2654         NaN        2498
# 48         Bu, Xiangzhi     CHI   38         2684      2290.0        2621
# 50  Tomashevsky, Evgeny    FIDE   36         2681      2365.0        2595
#
#     TOTAL GAMES  WINS  LOSSES  DRAWS  WIN RATE  LOSS RATE  DRAW RATE
# 5          1194   561     148    385  0.469849   0.123953   0.322446
# 98          585   229      76    280  0.391453   0.129915   0.478632
# 79         1516   611     197    708  0.403034   0.129947   0.467018
# 48         1968   757     260    951  0.384654   0.132114   0.483232
# 50         1817   578     244    995  0.318107   0.134287   0.547606

# %%
df.sort_values(by= "DRAW RATE",ascending = False).head() # Berabere oranı en yüksek 5 oyuncu
# Out:
#                    NAME COUNTRY  AGE  CURRENT ELO  12 AGE ELO  18 AGE ELO  \
# 67          Leko, Peter     HUN   44         2666      2460.0        2670
# 50  Tomashevsky, Evgeny    FIDE   36         2681      2365.0        2595
# 27    Radjabov, Teimour     AZE   37         2723      2459.0        2704
# 14          Giri, Anish     NET   29         2745      2261.0        2734
# 7            So, Wesley     ABD   30         2757      2411.0        2677
#
#     TOTAL GAMES  WINS  LOSSES  DRAWS  WIN RATE  LOSS RATE  DRAW RATE
# 67         2662   686     408   1568  0.257701   0.153268   0.589031
# 50         1817   578     244    995  0.318107   0.134287   0.547606
# 27         2136   622     382   1132  0.291199   0.178839   0.529963
# 14         2431   750     414   1267  0.308515   0.170300   0.521185
# 7          2279   778     317   1184  0.341378   0.139096   0.519526

# %%
df.sort_values(by= "DRAW RATE").head() # Berabere oranı en düşük 5 oyuncu
# Out:
#                   NAME COUNTRY  AGE  CURRENT ELO  12 AGE ELO  18 AGE ELO  \
# 54  Niemann, Hans Moke     ABD   20         2676      2342.0        2678
# 93        Pichot, Alan     ESP   25         2644      2242.0        2577
# 15            Gukesh D     IND   17         2743      2536.0        2758
# 52        Amin, Bassem     EGY   35         2678      2166.0        2535
# 78  Alekseenko, Kirill     AUS   26         2655      2251.0        2576
#
#     TOTAL GAMES  WINS  LOSSES  DRAWS  WIN RATE  LOSS RATE  DRAW RATE
# 54         1145   553     275    317  0.482969   0.240175   0.276856
# 93         1274   614     289    371  0.481947   0.226845   0.291209
# 15         1274   606     295    373  0.475667   0.231554   0.292779
# 52         1841   903     392    546  0.490494   0.212928   0.296578
# 78         1432   693     314    425  0.483939   0.219274   0.296788

# %%
df["COUNTRY"].value_counts()
# Out:
# FIDE     12
# ABD      12
# IND      10
# CHI       9
# UKR       5
# UZBEK     4
# AZE       4
# ARM       3
# ENG       3
# ESP       3
# ROM       3
# POL       3
# FRA       3
# CRO       2
# GER       2
# ISR       2
# IRAN      2
# SER       2
# NET       2
# HUN       2
# CZE       2
# AUS       1
# DEN       1
# SWE       1
# NOR       1
# SPA       1
# EGY       1
# SLO       1
# BUL       1
# VIET      1
# TUR       1
# Name: COUNTRY, dtype: int64

# %%
df_c = df[(df.COUNTRY == "ABD") | (df.COUNTRY == "FIDE") | (df.COUNTRY == "CHI") | (df.COUNTRY == "IND") ]
df_c
# Out:
#                           NAME COUNTRY  AGE  CURRENT ELO  12 AGE ELO  \
# 1             Caruana, Fabiano     ABD   31         2803      2381.0
# 2             Nakamura, Hikaru     ABD   36         2789      2356.0
# 4                  Ding, Liren     CHI   31         2762      2289.0
# 6          Nepomniachtchi, Ian    FIDE   33         2758      2432.0
# 7                   So, Wesley     ABD   30         2757      2411.0
# 8               Erigaisi Arjun     IND   20         2756      2379.0
# 9                      Wei, Yi     CHI   24         2755      2401.0
# 10          Anand, Viswanathan     IND   54         2751         NaN
# 11            Karjakin, Sergey    FIDE   34         2750      2547.0
# 12    Dominguez Perez, Leinier     ABD   40         2748      2205.0
# 13            Praggnanandhaa R     IND   18         2747      2532.0
# 15                    Gukesh D     IND   17         2743      2536.0
# 21              Aronian, Levon     ABD   41         2729      2355.0
# ...

# %%
df_c["COUNTRY"].value_counts()
# Out:
# ABD     12
# FIDE    12
# IND     10
# CHI      9
# Name: COUNTRY, dtype: int64

# %%
df_c.groupby(by = "COUNTRY")["CURRENT ELO"].describe()
# Out:
#          count         mean        std     min      25%     50%      75%  \
# COUNTRY
# ABD       12.0  2710.333333  54.161935  2642.0  2670.75  2696.5  2750.25
# CHI        9.0  2691.777778  47.306918  2641.0  2651.00  2684.0  2728.00
# FIDE      12.0  2696.000000  36.058034  2648.0  2662.75  2696.0  2712.25
# IND       10.0  2713.400000  36.996096  2654.0  2695.75  2714.0  2746.00
#
#             max
# COUNTRY
# ABD      2803.0
# CHI      2762.0
# FIDE     2758.0
# IND      2756.0

# %%
df_c.groupby(by = "COUNTRY")["AGE"].describe()
# Out:
#          count       mean        std   min    25%   50%    75%   max
# COUNTRY
# ABD       12.0  29.250000   7.200063  20.0  23.00  29.5  33.00  41.0
# CHI        9.0  33.222222   4.918785  24.0  31.00  34.0  37.00  40.0
# FIDE      12.0  35.416667   7.890827  22.0  31.50  35.0  40.75  47.0
# IND       10.0  26.200000  11.602682  17.0  18.25  22.0  28.25  54.0

# %%
df_c.groupby(by = "COUNTRY")["18 AGE ELO"].describe()
# Out:
#          count         mean        std     min      25%     50%      75%  \
# COUNTRY
# ABD       12.0  2639.666667  59.030552  2513.0  2609.00  2646.0  2677.25
# CHI        9.0  2623.222222  96.353227  2418.0  2586.00  2621.0  2691.00
# FIDE      12.0  2628.083333  67.006727  2495.0  2592.50  2620.0  2682.25
# IND       10.0  2651.300000  78.014315  2541.0  2590.75  2650.0  2715.75
#
#             max
# COUNTRY
# ABD      2721.0
# CHI      2753.0
# FIDE     2732.0
# IND      2758.0

# %%
for country in df_c["COUNTRY"].unique():
    sns.distplot(df_c[df_c["COUNTRY"] == country]["CURRENT ELO"],hist = False, label= country, kde_kws = {"shade" : True});

# %%
for country in df_c["COUNTRY"].unique():
    sns.distplot(df_c[df_c["COUNTRY"] == country]["18 AGE ELO"],hist = False, label= country, kde_kws = {"shade" : True});

# %%
for country in df_c["COUNTRY"].unique():
    sns.distplot(df_c[df_c["COUNTRY"] == country]["AGE"],hist = False, label= country, kde_kws = {"shade" : True});

# %%
chı_players = df_c[df_c["COUNTRY"] == "CHI"].iloc[:,[0, 2]]
chı_players
# Out:
#             NAME  AGE
# 4    Ding, Liren   31
# 9        Wei, Yi   24
# 23    Yu, Yangyi   29
# 35     Wang, Hao   34
# 48  Bu, Xiangzhi   38
# 81     Wang, Yue   37
# 83    Li, Chao b   34
# 86       Ni, Hua   40
# 98       Ma, Qun   32

# %%
for col in df_c.columns[3:6]:
    sns.scatterplot(data=df_c,x="AGE",y=col,hue = "COUNTRY")
    plt.show()

# %%
sns.boxplot(x="COUNTRY",y="CURRENT ELO",data=df_c);

# %%
sns.boxplot(x="COUNTRY",y="AGE",data=df_c); # Aykırı değer 54. Viswanathan Anand

# %%
sns.boxplot(x="COUNTRY",y="18 AGE ELO",data=df_c);

# %%
df.head()
# Out:
#                      NAME COUNTRY  AGE  CURRENT ELO  12 AGE ELO  18 AGE ELO  \
# 0         Carlsen, Magnus     NOR   33         2830      2450.0        2801
# 1        Caruana, Fabiano     ABD   31         2803      2381.0        2721
# 2        Nakamura, Hikaru     ABD   36         2789      2356.0        2664
# 3  Abdusattorov, Nodirbek   UZBEK   19         2765      2486.0        2734
# 4             Ding, Liren     CHI   31         2762      2289.0        2664
#
#    TOTAL GAMES  WINS  LOSSES  DRAWS  WIN RATE  LOSS RATE  DRAW RATE
# 0         3421  1536     527   1358  0.448992   0.154049   0.396960
# 1         3047  1187     641   1219  0.389564   0.210371   0.400066
# 2         3318  1426     567   1325  0.429777   0.170886   0.399337
# 3         1160   513     240    407  0.442241   0.206897   0.350862
# 4         1489   510     229    750  0.342512   0.153794   0.503694

# %%
df.AGE.value_counts()
# Out:
# 33    7
# 37    7
# 40    6
# 26    5
# 23    5
# 29    5
# 38    5
# 31    4
# 24    4
# 30    4
# 20    4
# 19    4
# 22    4
# 36    3
# 18    3
# 32    3
# 41    3
# 34    3
# 39    2
# 44    2
# 35    2
# 28    2
# 25    2
# 46    1
# 52    1
# 55    1
# 51    1
# 49    1
# 21    1
# 47    1
# 27    1
# 17    1
# 54    1
# 43    1
# Name: AGE, dtype: int64

# %%
def age_test(x):
    if x<30:
        return "YOUNG"
    elif 29<x<40:
        return "MIDDLE AGE"
    else:
        return "OLD"

# %%
df["AGE CATEGORY"] = df["AGE"].apply(age_test)
df.head(11)
# Out:
#                       NAME COUNTRY  AGE  CURRENT ELO  12 AGE ELO  18 AGE ELO  \
# 0          Carlsen, Magnus     NOR   33         2830      2450.0        2801
# 1         Caruana, Fabiano     ABD   31         2803      2381.0        2721
# 2         Nakamura, Hikaru     ABD   36         2789      2356.0        2664
# 3   Abdusattorov, Nodirbek   UZBEK   19         2765      2486.0        2734
# 4              Ding, Liren     CHI   31         2762      2289.0        2664
# 5        Firouzja, Alireza     FRA   20         2760      2485.0        2804
# 6      Nepomniachtchi, Ian    FIDE   33         2758      2432.0        2634
# 7               So, Wesley     ABD   30         2757      2411.0        2677
# 8           Erigaisi Arjun     IND   20         2756      2379.0        2725
# 9                  Wei, Yi     CHI   24         2755      2401.0        2753
# 10      Anand, Viswanathan     IND   54         2751         NaN        2555
#
# ...

# %%
df["AGE CATEGORY"].value_counts()
# Out:
# YOUNG         41
# MIDDLE AGE    40
# OLD           19
# Name: AGE CATEGORY, dtype: int64

# %%
df.groupby(by = "AGE CATEGORY")["CURRENT ELO"].describe()
# Out:
#               count         mean        std     min     25%     50%     75%  \
# AGE CATEGORY
# MIDDLE AGE     40.0  2691.700000  48.718553  2641.0  2654.0  2674.5  2725.0
# OLD            19.0  2686.526316  34.636795  2646.0  2661.0  2673.0  2716.5
# YOUNG          41.0  2696.512195  36.760796  2642.0  2668.0  2695.0  2727.0
#
#                  max
# AGE CATEGORY
# MIDDLE AGE    2830.0
# OLD           2751.0
# YOUNG         2765.0

# %%
df.groupby(by = "AGE CATEGORY")["18 AGE ELO"].describe()
# Out:
#               count         mean        std     min      25%     50%     75%  \
# AGE CATEGORY
# MIDDLE AGE     40.0  2609.675000  78.090476  2418.0  2570.75  2606.0  2664.0
# OLD            19.0  2601.315789  65.099968  2495.0  2565.50  2587.0  2641.5
# YOUNG          41.0  2661.780488  59.336967  2541.0  2626.00  2642.0  2701.0
#
#                  max
# AGE CATEGORY
# MIDDLE AGE    2801.0
# OLD           2743.0
# YOUNG         2804.0

# %%
for age_cat in df["AGE CATEGORY"].unique():
    sns.distplot(df[df["AGE CATEGORY"] == age_cat]["CURRENT ELO"],hist = False, label= age_cat, kde_kws = {"shade" : True});

# %%
for age_cat in df["AGE CATEGORY"].unique():
    sns.distplot(df[df["AGE CATEGORY"] == age_cat]["18 AGE ELO"],hist = False, label= age_cat, kde_kws = {"shade" : True});

# %%
for col in df.columns[3:6]:
    sns.scatterplot(data=df,x="AGE",y=col,hue = "AGE CATEGORY")
    plt.show()

# %%
sns.boxplot(x="AGE CATEGORY",y="CURRENT ELO",data=df);

# %%
sns.boxplot(x="AGE CATEGORY",y="18 AGE ELO",data=df);

# %% [markdown]
# ## Tahmin Modeli

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (86, 14)

# %%
y = df["18 AGE ELO"]
X = df.iloc[:,[2,4]]
X.head()
# Out:
#    AGE  12 AGE ELO
# 0   33      2450.0
# 1   31      2381.0
# 2   36      2356.0
# 3   19      2486.0
# 4   31      2289.0

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet

from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
import xgboost
from xgboost import XGBRegressor

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.25, 
                                                    random_state=42)

# %%
models = []

models.append(('Regression', LinearRegression()))
models.append(('Ridge', Ridge()))
models.append(('Lasso', Lasso()))
models.append(('ElasticNet', ElasticNet()))
models.append(('KNN', KNeighborsRegressor()))
models.append(('CART', DecisionTreeRegressor()))
models.append(('RF', RandomForestRegressor()))
models.append(('SVR', SVR()))
models.append(('GBM', GradientBoostingRegressor()))
models.append(("XGBoost", XGBRegressor()))

for name, model in models:
    model.fit(X_train,y_train)
    y_pred=model.predict(X_test)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    score = model.score(X,y)
    print(name,rmse,score)
# Out:
# Regression 50.66474772295724 0.39573786339932004
# Ridge 50.665129159684234 0.395735763105986
# Lasso 50.68519159581883 0.39562231887217514
# ElasticNet 50.687110144184025 0.39561114031731337
# KNN 57.50969878677384 0.4296762531844718
# CART 57.17000166966143 0.8224865184076408
# RF 53.090786009352996 0.7631341097943605
# SVR 68.3849209157352 0.002567085811740033
# GBM 54.96983706058205 0.7850983674339976
# XGBoost 58.524572081658924 0.813973966652795

# %%
# En başarılı model Cart 0.82

# %% [markdown]
# ## Yağız Kaan Erdoğmuş : 2758

# %%
data = {'AGE': pd.Series([12]), '12 AGE ELO': pd.Series([2540])}
yağız = pd.DataFrame(data)
yağız
# Out:
#    AGE  12 AGE ELO
# 0   12        2540

# %%
d_tree = DecisionTreeRegressor()
d_tree_model = d_tree.fit(X,y)
d_tree_model.predict(yağız)
# Out:
# array([2758.])

# %% [markdown]
# ## Ediz Gürel : 2677

# %%
data = {'AGE': pd.Series([12]), '12 AGE ELO': pd.Series([2393])}
ediz = pd.DataFrame(data)
ediz
# Out:
#    AGE  12 AGE ELO
# 0   12        2393

# %%
d_tree = DecisionTreeRegressor()
d_tree_model = d_tree.fit(X,y)
d_tree_model.predict(ediz)
# Out:
# array([2677.])
